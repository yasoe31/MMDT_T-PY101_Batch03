# %% [markdown]
# <a href="https://colab.research.google.com/github/myothida/PythonProgramming/blob/main/Ex1_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introduction

# %% [markdown]
# This section introduces the Python Programming uisng Colab. Follow the instructions and complete the exercises.

# %% [markdown]
# # Ex 1 : Check Version

# %% [markdown]
# Using the below cell, Import the required library and check the version of the python in your environment.

# %%
import sys
print (sys.version)
# Out:
# 3.10.12 (main, Nov  4 2025, 08:48:33) [GCC 11.4.0]

# %% [markdown]
# # Ex2 : Convert Currency.

# %% [markdown]
# Write a program that asks the user for the amount in usd and converts it to British pounds. The exchange rate is from usd to BP is given as 0.82

# %%
usd_amount = input ("Enter the amount in USD: ")
bp_amount = int(usd_amount) *0.82
print("{} usd is equivalent to {} british pound".format(usd_amount, bp_amount))
# Out:
# Enter the amount in USD:  10
# 10 usd is equivalent to 8.2 british pound

# %% [markdown]
# # Ex 3: Temperature Converter

# %% [markdown]
# Write a program that convert temperature in Feranhite to celsius.

# %%
feranhite = input("Enter the temperature in Feranhite")
celsius = ((float(feranhite) - 32) * 5)/9
print("{} Feranhite is in {} celsius".format(feranhite,celsius))
# Out:
# Enter the temperature in Feranhite 20
# 20 Feranhite is in -6.666666666666667 celsius

# %% [markdown]
# # Ex 4: Daily Maths

# %% [markdown]
# You are working in a retail shop. Write a program that computes the total cost for a customer that bought 3 differnt types of fruits : apple, orange, mango. Ask the user to enter the quantity and price for each type.

# %%
noOfApple = input("Enter number of apple")
applePrice = input("Enter the price of an apple")

noOfOrange = input("Enter number of Orange")
orangePrice = input("Enter the price of an Orange")

noOfMango = input("Enter number of Mange")
mangoPrice = input("Enter the price of a Mango")

total = (int(noOfApple) * float(applePrice)) + (int(noOfOrange) * float(orangePrice)) + (int(noOfMango) * float(mangoPrice))
print("Total = {}".format(total))
# Out:
# Enter number of apple 3
# Enter the price of an applea 1.2
# Enter number of Orange 5
# Enter the price of an Orange 1.5
# Enter number of Mange 4
# Enter the price of a Mango 2.5
# Total = 21.1

# %% [markdown]
# # Ex 5 : Greeting

# %% [markdown]
# Write a program to greet the customer who provides the user name. Your program should ask the name of the customer and print "Hello + customer name"

# %%
name = input("Enter your name")
print("Hello {}".format(name))
# Out:
# Enter your name Yas
# Hello Yas

# %% [markdown]
# # Ex 6: Random Number
# Write a program that generates a random number, x, between 1 and 50, a random number y between 2 and 5, and computes x^y.

# %%
from random import randint
x = randint(1,50)
y = randint(2,5)
print('A random number X between 1 and 50: ', x)
print('A random number Y between 2 and 5: ',y)
print('Result : ',x^y)
# Out:
# A random number X between 1 and 50:  2
# A random number Y between 2 and 5:  5
# Result :  7

# %% [markdown]
# # Ex 7: Greet many times.
# Write a program that generates a random number between 1 and 10 and prints your name that many times.

# %%
from random import randint
name = 'yas'
randomNumber = randint(1,10)
print(randomNumber)
print(randomNumber*name)
# Out:
# 7
# yasyasyasyasyasyasyas

# %% [markdown]
# # Ex 8: Computing.
# Write a program that asks the user to enter two numbers, x and y, and computes |x-y|/(x+y).

# %%
x = input("Enter a number")
y = input("Enter a number")
intx = int(x)
inty = int(y)
result = (abs(intx - inty))/(intx+inty)
print("Result {}",result)
# Out:
# Enter a number 3
# Enter a number 4
# Result {} 0.14285714285714285

# %% [markdown]
# # Ex 9: Computing
#
# Write a program that asks the user for a number of seconds and prints out how many minutes and seconds that is. For instance, 200 seconds is 3 minutes and 20 seconds.

# %%
import math
userInput = input("Enter a number of seconds ")
userInputInt = int(userInput)
if userInputInt >= 60 :
  minutes = userInputInt/60
  seconds = userInputInt % 60

print("{} minutes and {} seconds".format(math.floor(minutes),seconds))
# Out:
# Enter a number of seconds  75
# 1 minutes and 15 seconds

# %% [markdown]
# # Ex 10: Using Math Module
#
# Write a program that asks the user for a number and then prints out the sine, cosine, and tangent of that number.

# %%
import math
num = float(input("Enter a number:"))

angle_rad = math.radians(int(num))   # convert degrees to radians

sine_value = math.sin(angle_rad)
cosine_value = math.cos(angle_rad)
tangent_value = math.tan(angle_rad)
print("sine {}, cosine {}, tangent {}".format(sine_value,cosine_value,tangent_value))
# Out:
# Enter a number: 25
# sine 0.42261826174069944, cosine 0.9063077870366499, tangent 0.4663076581549986
